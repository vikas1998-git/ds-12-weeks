# %%
import numpy as np
import pandas as pd

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)

arr = np.array([10, 20, 30])
print("Test Array Matrix:", arr * 5)
# Out:
# NumPy: 2.5.2
# Pandas: 3.0.5
# Test Array Matrix: [ 50 100 150]
